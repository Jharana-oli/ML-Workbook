# %%
import pandas as pd

# %%
info ={
    "Name":["Jharana","Kyurisha","Abantika","Nikita"],
    "CGPA":[9.8,9.8,9.8,9.8]
}
data_frame=pd.DataFrame(info)
print(data_frame)
# Out:
#        Name  CGPA
# 0   Jharana   9.8
# 1  Kyurisha   9.8
# 2  Abantika   9.8
# 3    Nikita   9.8

# %%
#series
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
age=pd.Series([21,21,22,22],index=["Jharana","Kyurisha","Abantika","Nikita"])
print(age)
print(age["Jharana"])
# Out:
# Jharana     21
# Kyurisha    21
# Abantika    22
# Nikita      22
# dtype: int64
