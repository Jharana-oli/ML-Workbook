# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
import torch.nn as nn

# %%
#input
input=torch.tensor([1.0,2.0,3.0])

# %%
neuron=nn.Linear(in_features=3,out_features=1)

# %%
output=neuron(input)

# %%
output
# Out:
# tensor([-1.7805], grad_fn=<ViewBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[-0.1657, -0.0823, -0.3310]], requires_grad=True)
